# %%
import MBWrapper
import wandb

# %%
wrapper = MBWrapper.MBWrapper(5, 7, "gpt2", gpu=2, batch_size=128, model_length=141)

# %%
result = wrapper.main()
print(result)
# Out:
# There are 4 GPU(s) available.
# Device name: NVIDIA A100-SXM4-40GB
# Some weights of GPT2ForSequenceClassification were not initialized from the model checkpoint at gpt2 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model Downloaded
# Start Tokenizing
# Finish Tokenizing
# Training Initialized for fold 0
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /beegfs/zhukova/.netrc
# wandb: Currently logged in as: media-bias. Use `wandb login --relogin` to force relogin
# ...
