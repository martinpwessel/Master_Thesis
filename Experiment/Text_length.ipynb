# %%
import MBDataLoader

# %%
loader = MBDataLoader.MBDataLoader(8)
df = loader.load_balanced_sample()
loader.text_length_analysis(df)
# Out:
# Removed 4 duplicates
# The Category consists of 49.250476969201415% biased and 50.749523030798585% non-biased labels.
# There are 0 texts longer than 512. That's 0.0%.
# There are 0 texts longer than 256. That's 0.0%.
# The 99% percentile is at 67.0
