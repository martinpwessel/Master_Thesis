# %%
from shutil import copyfile
import torch
# copy our file into the working directory (make sure it has .py suffix)
copyfile(src = "../input/proxytraining/Proxy_training.py", dst = "../working/Proxy_training.py")

# import all our functions
from Proxy_training import ProxyTraining, DataLoad

# %%
from transformers import XLMRobertaForSequenceClassification, XLMRobertaTokenizer
xlm_roberta_tokenizer = XLMRobertaTokenizer.from_pretrained('xlm-roberta-base')
xlm_roberta_model = XLMRobertaForSequenceClassification.from_pretrained('xlm-roberta-base', num_labels=2)
proxy_xlm_roberta = ProxyTraining(xlm_roberta_tokenizer, 4)
proxy_xlm_roberta.proxy_train_main(xlm_roberta_model, 32, gpu_no=0, model_name="xlm_roberta")
# Out:
# Downloading: 100%|██████████| 5.07M/5.07M [00:00<00:00, 6.45MB/s]
# Downloading: 100%|██████████| 615/615 [00:00<00:00, 1.03MB/s]
# Downloading: 100%|██████████| 1.12G/1.12G [00:12<00:00, 91.5MB/s]
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['lm_head.dense.bias', 'roberta.pooler.dense.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
#CharacterBERT
torch.cuda.empty_cache()
from transformers import AutoTokenizer, AutoModelForSequenceClassification
characterbert_tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
characterbert_model = AutoModelForSequenceClassification.from_pretrained('imvladikon/general_character_bert', num_labels=2)
proxy_characterbert = ProxyTraining(characterbert_tokenizer, 4)
proxy_characterbert.proxy_train_main(characterbert_model, 32, gpu_no=0, model_name="CharacterBERT")
# Out:
# Downloading: 100%|██████████| 466k/466k [00:00<00:00, 937kB/s]
# Downloading: 100%|██████████| 1.21k/1.21k [00:00<00:00, 2.02MB/s]
# Downloading: 100%|██████████| 418M/418M [00:10<00:00, 39.1MB/s]
# ...

# %%
torch.cuda.empty_cache()
from transformers import AutoTokenizer, AutoModelForSequenceClassification
mirror_bert_tokenizer = AutoTokenizer.from_pretrained("cambridgeltl/mirror-bert-base-uncased-word")
mirror_bert_tokenizer.add_special_tokens({'pad_token': '[PAD]'})
mirror_bert_model = AutoModelForSequenceClassification.from_pretrained("cambridgeltl/mirror-bert-base-uncased-word", num_labels=2)
#mirror_bert_model.config.pad_token_id = mirror_bert_tokenizer.pad_token_id
proxy_mirror_bert = ProxyTraining(mirror_bert_tokenizer, 4)
proxy_mirror_bert.proxy_train_main(mirror_bert_model, 8, gpu_no=0, model_name = "Mirror-BERT")
# Out:
# ...
# Downloading: 100%|██████████| 599/599 [00:00<00:00, 1.02MB/s]
# Downloading: 100%|██████████| 232k/232k [00:00<00:00, 527kB/s]
# Downloading: 100%|██████████| 112/112 [00:00<00:00, 50.4kB/s]
# Downloading: 100%|██████████| 438M/438M [00:25<00:00, 17.5MB/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cambridgeltl/mirror-bert-base-uncased-word and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# There are 4 GPU(s) available.
# Device name: NVIDIA A100-SXM4-40GB
# Fold 1
#  25%|██▌       | 369/1472 [01:19<38:03,  2.07s/it]
# Fold: 0 Epoch 0: Avg train loss: 0.5352500081062317, Avg test loss: 0.45457199215888977 Avg test acc: {'accuracy': 0.7959183673469388}, Avg test f1: {'f1': 0.8086734693877551}
#  50%|████▉     | 735/1472 [02:28<02:19,  5.27it/s]
# Early Stopping Criteria
# ...

# %%
torch.cuda.empty_cache()
from transformers import BertModel,BertTokenizer, BertForSequenceClassification

bert_tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
bert_model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=2)
proxy_bert = ProxyTraining(bert_tokenizer, 4)
proxy_bert.proxy_train_main(bert_model, 32, gpu_no= 0, model_name= "BERT")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
#GPT2
torch.cuda.empty_cache()
from transformers import GPT2ForSequenceClassification, GPT2Tokenizer
gpt2_tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
gpt2_tokenizer.pad_token = gpt2_tokenizer.eos_token
gpt2_model = GPT2ForSequenceClassification.from_pretrained('gpt2', num_labels=2)
gpt2_model.config.pad_token_id = gpt2_tokenizer.pad_token_id
proxy_gpt2 = ProxyTraining(gpt2_tokenizer, 4)
proxy_gpt2.proxy_train_main(gpt2_model, 4, gpu_no=0, model_name= "GPT-2")
# Out:
# Some weights of GPT2ForSequenceClassification were not initialized from the model checkpoint at gpt2 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# There are 4 GPU(s) available.
# Device name: NVIDIA A100-SXM4-40GB
#   0%|          | 0/736 [01:24<?, ?it/s]
# Fold 1
#  25%|██▌       | 735/2940 [03:04<07:53,  4.66it/s]
# Fold: 0 Epoch 0: Avg train loss: 0.6526354551315308, Avg test loss: 0.4220130443572998 Avg test acc: {'accuracy': 0.8095238095238095}, Avg test f1: {'f1': 0.8028169014084506}
#  50%|█████     | 1470/2940 [06:28<05:15,  4.65it/s]
# Early Stopping Criteria
# Fold: 0 Epoch 1: Avg train loss: 0.3853622078895569, Avg test loss: 0.4489716589450836 Avg test acc: {'accuracy': 0.8040816326530612}, Avg test f1: {'f1': 0.7728706624605677}
# Fold 2
#  50%|█████     | 1470/2940 [06:48<06:48,  3.60it/s]
#
# ...
#  25%|██▌       | 735/2940 [03:04<07:54,  4.64it/s]
# ...

# %%
# ConvBERT
torch.cuda.empty_cache()
from transformers import ConvBertForSequenceClassification, ConvBertTokenizer
convbert_tokenizer = ConvBertTokenizer.from_pretrained('YituTech/conv-bert-base')
convbert_model = ConvBertForSequenceClassification.from_pretrained('YituTech/conv-bert-base', num_labels=2)
proxy_convbert = ProxyTraining(convbert_tokenizer, 4)
proxy_convbert.proxy_train_main(convbert_model, 32, gpu_no=0, model_name= "ConvBERT")
# Out:
# Downloading: 100%|██████████| 267k/267k [00:01<00:00, 163kB/s]
# Downloading: 100%|██████████| 674/674 [00:00<00:00, 969kB/s]
# Downloading: 100%|██████████| 423M/423M [00:22<00:00, 19.1MB/s]
# Some weights of ConvBertForSequenceClassification were not initialized from the model checkpoint at YituTech/conv-bert-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# There are 4 GPU(s) available.
# Device name: NVIDIA A100-SXM4-40GB
# Fold 1
#  25%|██▌       | 92/368 [01:03<02:53,  1.59it/s]
# Fold: 0 Epoch 0: Avg train loss: 0.5129250288009644, Avg test loss: 0.3969365954399109 Avg test acc: {'accuracy': 0.8231292517006803}, Avg test f1: {'f1': 0.8121387283236994}
#  50%|█████     | 184/368 [02:22<01:55,  1.59it/s]
# Early Stopping Criteria
# ...

# %%
#FunnelTransformer
torch.cuda.empty_cache()
from transformers import AutoTokenizer, AutoModelForSequenceClassification
funnel_transformer_tokenizer = AutoTokenizer.from_pretrained("funnel-transformer/medium-base")
funnel_transformer_tokenizer.pad_token = funnel_transformer_tokenizer.eos_token
funnel_transformer_model = AutoModelForSequenceClassification.from_pretrained('funnel-transformer/medium-base', num_labels=2)
funnel_transformer_model.config.pad_token_id = funnel_transformer_tokenizer.pad_token_id
proxy_funnel_transformer = ProxyTraining(funnel_transformer_tokenizer, 4)
proxy_funnel_transformer.proxy_train_main(funnel_transformer_model, 8, gpu_no=0, model_name= "FunnelTransformer")
# Out:
# ...
# Downloading: 100%|██████████| 704/704 [00:00<00:00, 933kB/s]
# Downloading: 100%|██████████| 231k/231k [00:00<00:00, 521kB/s]
# Downloading: 100%|██████████| 466k/466k [00:00<00:00, 1.10MB/s]
# Downloading: 100%|██████████| 153/153 [00:00<00:00, 221kB/s]
# Downloading: 100%|██████████| 462M/462M [00:35<00:00, 13.2MB/s]
# Some weights of FunnelForSequenceClassification were not initialized from the model checkpoint at funnel-transformer/medium-base and are newly initialized: ['classifier.linear_hidden.bias', 'classifier.linear_hidden.weight', 'classifier.linear_out.bias', 'classifier.linear_out.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# There are 4 GPU(s) available.
# Device name: NVIDIA A100-SXM4-40GB
# Fold 1
#  25%|██▍       | 367/1472 [01:29<04:28,  4.12it/s]
# ...

# %%
#BigBird
torch.cuda.empty_cache()
from transformers import BigBirdForSequenceClassification, BigBirdTokenizer
bigbird_tokenizer = BigBirdTokenizer.from_pretrained("google/bigbird-roberta-base")
bigbird_model = BigBirdForSequenceClassification.from_pretrained("google/bigbird-roberta-base", num_labels = 2)
proxy_bigbird = ProxyTraining(bigbird_tokenizer, 4)
proxy_bigbird.proxy_train_main(bigbird_model, 4, gpu_no=0, model_name="BigBird")
# Out:
# Some weights of the model checkpoint at google/bigbird-roberta-base were not used when initializing BigBirdForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BigBirdForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BigBirdForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...
